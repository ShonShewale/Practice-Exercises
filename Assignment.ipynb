# %%
# Q1: Create a variable called name and store any string in it.
name=str("shon")
print(name)
# Out:
# shon

# %%
# Q2: Create two integer variables and print their sum.
a=12
b=13
print(a+b)
# Out:
# 25

# %%
# Q3: Create two float variables and print their product.
a=6.9
b=9.6
print(a*b)
# Out:
# 66.24

# %%
# Q4: Take a number variable and check if it is positive using if.
a=18
if a>0:
  print("it is positive")
# Out:
# it is positive

# %%
# Q5: Use if-else to check whether a number is even or odd.
a=-3
if a%2==0:
  print("The number is even")
else:
  print("The number is odd ")
# Out:
# The number is odd

# %%
# Q6: Use if-else to check whether a person is eligible to vote (age >= 18).
age=21
if age>=18:
  print("eligible for vote")
else:
  print("not eligible for voting")
# Out:
# eligible for vote

# %%
# Q7: Create three variables and print the largest using if-elif-else.
a=32
b=23
c=45
if a>b and a>c:
  print("A is Greater")
elif b>a and b>c:
  print("B is Greater")
else:
  print("C is Greater")
# Out:
# C is Greater

# %%
# Q8: Write a program to check if a number is divisible by 5.
a=50
if a%5==0:
  print(f"{a}is divisible by 5")
else:
  print(f"{a}is not divisible by 5" )
# Out:
# 50is divisible by 5

# %%
# Q9: Write a nested if to check if a number is positive and also even.
a=-23

if a>0:
  print("The no is positive")
  if a%2==0:
    print("The no is even")
  else:
    print("The no is odd")
else:
  print("The no is negative")
# Out:
# The no is negative

# %%
# Q10: Write a program that prints 'Pass' if marks > 40 else 'Fail'.
marks=35
if marks>=40:
  print("pass")
else:
  print("Fail")
# Out:
# Fail

# %%
# Q11: Write a program to check if a number is between 10 and 20.
a=21
if a>=10 and a<=20:
  print("yes")
else:
  print("not")
# Out:
# not

# %%
# Q12: Write a program to check if a character is a vowel.
character="b"
if character=='a' or character=='e' or character=='i' or character=='o' or character=='u':
  print("is vowel")
else:
  print("is not vowel")
# Out:
# is not vowel

# %%
# Q13: Write a nested if to check if a person is a teenager (13–19).
age=22
if age>=13:
  if age<=19:
    print("is teenager")
  else:
    print("is adult")
else:
  print("is not teenager")
# Out:
# is adult

# %%
# Q14: Create a variable temperature and print 'Hot', 'Warm', or 'Cold' using elif.
temperature=18
if temperature<=15:
  print("it is cold")
elif temperature<=30:
  print("it is warm")
else:
  print("it is hot")
# Out:
# it is warm

# %%
# Q15: Check whether a number is a multiple of both 3 and 7.

# %%
# Q16: Write a program to compare two strings for equality.

# %%
# Q17: Write a program to check if a number is positive, negative, or zero.
a=0
if a>0:
  print("the no is positive")
elif a<0:
  print("the no is negative")
else:
  print("the no is zero")
# Out:
# the no is zero

# %%
# Q18: Use logical operator and to check if age is between 18 and 60.
age=61
if age>=18 and age<=60:
  print("yes")
else:
  print("not")
# Out:
# not

# %%
# Q19: Write a program to check if the last digit of a number is even.

# %%
# Q20: Write nested if to determine if a vehicle speed is safe (<60) or needs warning (>60).
speed=90
if speed<60:
  print("is safe")
else:
  print("warning")
# Out:
# warning

# %%
# Q21: Check if a number is a single-digit number.

# %%
# Q22: Write a program to check if a password length is at least 8.

# %%
# Q23: Use if-else to classify a number as small (<10), medium (<50), or large.
number=47
if number<10:
  print("is small")
elif number<50:
  print("is medium")
else:
  print("is large")
# Out:
# is medium

# %%
# Q24: Check if two variables have the same datatype (using type()).
a=12
b=23
if type(a)==type(b):
  print("have same type")
else:
  print("have not same type")
# Out:
# have same type

# %%
# Q25: Write a program to check if a number is divisible by both 2 and 4.
a=40
if a%2==0 and a%4==0:
  print("is divisible")
else:
  print("is not divisible")
# Out:
# is divisible

# %%
# Q26: Use nested if to check if someone is a child (<12), teen (<18), or adult.
age=10

if age<12:
  print("is child")
elif age<18:
  print("is teen")
else:
  print("is adult")
# Out:
# is child

# %%
# Q27: Write a program to check if a number ends with digit 5.

# %%
# Q28: Use comparison operators to check which number is greater.
a=23
b=24

if a>b:
  print("A is Greater")
else:
  print("B is Greater")
# Out:
# B is Greater

# %%
# Q29: Write a program to check if a variable is of type string.
a="is_student"
if type(a)==str:
  print("it is string")
else:
  print("it is not string")
# Out:
# it is string

# %%
# Q30: Use if-elif-else to check grading: A (90+), B (75+), C (60+), D (40+), Fail.
grade=100
if grade>=90:
  print("A")
elif grade>=75:
  print("B")
elif grade>=60:
  print("C")
elif grade>=40:
  print("D")
else:
  print("Fail")
# Out:
# A
